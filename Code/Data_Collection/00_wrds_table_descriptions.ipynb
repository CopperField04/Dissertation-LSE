# %% [markdown]
# # Seeing what is inside the following datasets:
#
# - 2 S&P500 Constituent Lists: crsp_a_indexes.dsp500list, crsp_a_indexes.dsp500list_v2
# - 1 General Stock Data list: crsp_a_stock.dsf_v2

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description_v1 = conn.describe_table(library='crsp_a_indexes', table='dsp500list')

print(description_v1)


conn.close()
# Out:
# Loading library list...
# Done
# Approximately 2064 rows in crsp_a_indexes.dsp500list.
#      name  nullable     type                                         comment
# 0  permno      True  INTEGER                           CRSP Permanent Number
# 1   start      True     DATE    Date when the stock included in S&P500 Index
# 2  ending      True     DATE  Date when the stock excluded from S&P500 Index

# %% [markdown]
# # General Stock Data: crsp_a_stock.dsf_v2

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='crsp_a_stock', table='dsf_v2')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 110245383 rows in crsp_a_stock.dsf_v2.
#                 name  nullable             type  \
# 0             permno      True          INTEGER
# 1           hdrcusip      True       VARCHAR(8)
# 2             permco      True          INTEGER
# 3              siccd      True          INTEGER
# 4         nasdissuno      True          INTEGER
# 5           yyyymmdd      True          INTEGER
# 6          sharetype      True       VARCHAR(3)
# 7       securitytype      True       VARCHAR(4)
# 8    securitysubtype      True       VARCHAR(3)
# 9           usincflg      True       VARCHAR(1)
# 10        issuertype      True       VARCHAR(4)
# 11       primaryexch      True       VARCHAR(1)
# 12   conditionaltype      True       VARCHAR(3)
# 13  tradingstatusflg      True       VARCHAR(1)
# 14          dlycaldt      True             DATE
# 15         dlydelflg      True       VARCHAR(1)
# 16            dlyprc      True   NUMERIC(13, 6)
# ...

# %% [markdown]
# # US Treasury and Inflation Data
# crsp_a_indexes.mcti

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='crsp_a_indexes', table='mcti')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 1189 rows in crsp_a_indexes.mcti.
#       name  nullable            type                                 comment
# 0    caldt      True            DATE                           Calendar Date
# 1   b30ret      True   NUMERIC(9, 6)                    30 Year Bond Returns
# 2   b30ind      True  NUMERIC(10, 6)      Index Level Associated with B30RET
# 3   b20ret      True   NUMERIC(9, 6)                    20 Year Bond Returns
# 4   b20ind      True  NUMERIC(10, 6)      Index Level Associated with B20RET
# 5   b10ret      True   NUMERIC(9, 6)                    10 Year Bond Returns
# 6   b10ind      True  NUMERIC(10, 6)      Index Level Associated with B10RET
# 7    b7ret      True   NUMERIC(9, 6)                     7 Year Bond Returns
# 8    b7ind      True  NUMERIC(10, 6)       Index Level Associated with B37ET
# 9    b5ret      True   NUMERIC(9, 6)                     5 Year Bond Returns
# ...

# %% [markdown]
# # Intraday Indicators
#
# taqmsec.wrds_iid_2024

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='taqmsec', table='wrds_iid_2024')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 2708911 rows in taqmsec.wrds_iid_2024.
#                        name  nullable     type  \
# 0                      date      True     DATE
# 1                  sym_root      True     TEXT
# 2                sym_suffix      True     TEXT
# 3           buynumtrades_lr      True  INTEGER
# 4          sellnumtrades_lr      True  INTEGER
# ..                      ...       ...      ...
# 203        total_dv_inst50k      True  NUMERIC
# 204   avg_buy_price_inst50k      True  NUMERIC
# 205  avg_sell_price_inst50k      True  NUMERIC
# 206    bs_ratio_inst50k_num      True  NUMERIC
# 207    bs_ratio_inst50k_vol      True  NUMERIC
#
#                                                comment
# 0                                                 Date
# 1                                 Security symbol root
# 2                               Security symbol suffix
# 3                     Total Number of Buys (Lee Ready)
# ...

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

tables = conn.list_tables(library='cboe')
print(tables)
conn.close()
# Out:
# Loading library list...
# Done
# ...

# %% [markdown]
# # VIX Data
#
# cboe.cboe

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='cboe', table='cboe')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 10656 rows in cboe.cboe.
#     name  nullable            type                               comment
# 0   date      True            DATE                                  Date
# 1   vixo      True  NUMERIC(11, 2)   CBOE S&P500 Volatility Index - Open
# 2   vixh      True  NUMERIC(11, 2)   CBOE S&P500 Volatility Index - High
# 3   vixl      True  NUMERIC(11, 2)    CBOE S&P500 Volatility Index - Low
# 4    vix      True  NUMERIC(11, 2)  CBOE S&P500 Volatility Index - Close
# 5   vxoo      True  NUMERIC(11, 2)   CBOE S&P100 Volatility Index - Open
# 6   vxoh      True  NUMERIC(11, 2)   CBOE S&P100 Volatility Index - High
# 7   vxol      True  NUMERIC(11, 2)    CBOE S&P100 Volatility Index - Low
# 8    vxo      True  NUMERIC(11, 2)  CBOE S&P100 Volatility Index - Close
# 9   vxno      True  NUMERIC(11, 2)   CBOE NASDAQ Volatility Index - Open
# 10  vxnh      True  NUMERIC(11, 2)   CBOE NASDAQ Volatility Index - High
# ...

# %% [markdown]
# # Currency Exchange Rates
#
# factset_common.fx_rates_usd

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='factset_common', table='fx_rates_usd')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 3469413 rows in factset_common.fx_rates_usd.
#                 name  nullable              type  \
# 0       iso_currency      True        VARCHAR(3)
# 1               date      True              DATE
# 2      exch_rate_usd      True  DOUBLE PRECISION
# 3  exch_rate_per_usd      True  DOUBLE PRECISION
#
#                                       comment
# 0              Code representing the currency
# 1                   Date of the exchange rate
# 2  Exchange rate - ISO_Currency in US Dollars
# 3  Exchange rate - ISO_Currency per US Dollar

# %% [markdown]
# # Pastor-Stambaugh Liquidity Factors
#
# ff_all.liq_ps

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='ff_all', table='liq_ps')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 749 rows in ff_all.liq_ps.
#        name  nullable              type                             comment
# 0    yearmm      True  DOUBLE PRECISION                                None
# 1      date      True              DATE       Last Trading Day of the Month
# 2  ps_level      True  DOUBLE PRECISION       Levels of aggregate liquidity
# 3  ps_innov      True  DOUBLE PRECISION  Innovations in aggregate liquidity
# 4    ps_vwf      True  DOUBLE PRECISION             Traded liquidity factor

# %% [markdown]
# # Fama French 5 Factors
#
# ff_all.fivefactors_daily
# ff_all.fivefactors_monthly

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='ff_all', table='fivefactors_daily')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 15288 rows in ff_all.fivefactors_daily.
#     name  nullable           type  \
# 0   date      True           DATE
# 1  mktrf      True  NUMERIC(8, 6)
# 2    smb      True  NUMERIC(8, 6)
# 3    hml      True  NUMERIC(8, 6)
# 4    rmw      True  NUMERIC(8, 6)
# 5    cma      True  NUMERIC(8, 6)
# 6     rf      True  NUMERIC(7, 5)
# 7    umd      True  NUMERIC(8, 6)
#
#                                              comment
# 0                                               Date
# 1                        Excess Return on the Market
# 2                             Small-Minus-Big Return
# 3                              High-Minus-Low Return
# 4                           Robust Minus Weak Return
# 5               Conservative Minus Aggressive Return
# 6  Risk-Free Return Rate (One Month Treasury Bill...
# 7                                           Momentum

# %% [markdown]
# # Daily World Indices
# wrdsapps_windices.dwcountryreturns

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='wrdsapps_windices', table='dwcountryreturns')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 291586 rows in wrdsapps_windices.dwcountryreturns.
#        name  nullable              type  \
# 0       fic      True        VARCHAR(3)
# 1      date      True              DATE
# 2   portret      True  DOUBLE PRECISION
# 3  portretx      True  DOUBLE PRECISION
# 4         n      True  DOUBLE PRECISION
# 5   country      True       VARCHAR(45)
# 6  currency      True        VARCHAR(3)
#
#                                   comment
# 0        ISO Country Code - Incorporation
# 1                                    Date
# 2     Daily Country Return with Dividends
# 3  Daily Country Return without Dividends
# 4   Number of securities in the portfolio
# 5                            Country Name
# 6                Currency of stock prices

# %% [markdown]
# # OptionSuite WRDS
#
# # API KEY DOES NOT EXIST FOR THIS
#
# For optionmetrics, the data not the factors, the library is optionm

# %% [markdown]
# # Linking everything to PERMNO and Date
#
# Intraday: Uses symroot or symsuffix
#
# crsp_a_stock.dsf_v2 uses PERMNO
#
# dsp500list uses PERMNO
#
# OpenAssetPricing uses GVKEY
#
#
# For TAQ data, join PERMNO with SYMROOT, use wrdsapps.taqmclink
#
# crsp.ccmxpf_lnkhist

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='wrdsapps', table='taqmclink')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 27705042 rows in wrdsapps.taqmclink.
#          name  nullable              type                 comment
# 0        date      True              DATE                    Date
# 1    sym_root      True        VARCHAR(6)    Security symbol root
# 2  sym_suffix      True       VARCHAR(10)  Security symbol suffix
# 3      permno      True           INTEGER                  PERMNO
# 4       cusip      True        VARCHAR(8)            CUSIP Header
# 5      ncusip      True        VARCHAR(8)                   CUSIP
# 6      shrcls      True        VARCHAR(4)      Share Class (CRSP)
# 7      ticker      True        VARCHAR(8)    Ticker Symbol (CRSP)
# 8   match_lvl      True  DOUBLE PRECISION             Match Level

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='crsp', table='ccmxpf_lnkhist')


print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 120083 rows in crsp.ccmxpf_lnkhist.
#         name  nullable              type  \
# 0      gvkey      True        VARCHAR(6)
# 1   linkprim      True        VARCHAR(1)
# 2       liid      True        VARCHAR(3)
# 3   linktype      True        VARCHAR(2)
# 4    lpermno      True  DOUBLE PRECISION
# 5    lpermco      True  DOUBLE PRECISION
# 6     linkdt      True              DATE
# 7  linkenddt      True              DATE
#
#                                            comment
# 0                   Standard and Poor's Identifier
# 1                              Primary Link Marker
# 2                        Security-level Identifier
# 3                                   Link Type Codd
# 4  Historical CRSP PERMNO Link to COMPUSTAT Record
# 5  Historical CRSP PERMCO Link to COMPUSTAT Record
# 6                     First Effective Date of Link
# 7                      Last Effective Date of Link

# %% [markdown]
# # Printing the Output from the top 5 rows of each dataset

# %% [markdown]
# # TAQ Factors

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

contents = conn.raw_sql("SELECT * FROM taqmsec.wrds_iid_2023 LIMIT 5")

print(contents)

conn.close()
# Out:
# Loading library list...
# Done
#          date sym_root sym_suffix  buynumtrades_lr  sellnumtrades_lr  \
# 0  2023-01-03        A       <NA>            12805             15582
# 1  2023-01-03       AA       <NA>            17962             17924
# 2  2023-01-03      AAA       <NA>                5                 2
# 3  2023-01-03     AAAU       <NA>              423               310
# 4  2023-01-03      AAC       <NA>              995               792
#
#    total_trade  buyvol_lr  sellvol_lr  total_vol  avg_buy_price_lr  ...  \
# 0        28387     523952      490781    1014733        149.535577  ...
# 1        35886    1309289     1319026    2628315         45.125388  ...
# 2            7         10           2         12          24.37798  ...
# 3          733     194006      117705     311711         18.229254  ...
# 4         1787    2171818     2573452    4745270         10.096941  ...
#
#    sellnumtrades_inst50k  sellvol_inst50k  sell_dv_inst50k  \
# ...

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

contents = conn.raw_sql("SELECT * FROM taqmsec.wrds_iid_2023 LIMIT 5")

print(contents)

conn.close()

# %% [markdown]
# # VIX

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

contents = conn.raw_sql("SELECT * FROM cboe.cboe LIMIT 5")

print(contents)

conn.close()
# Out:
# Loading library list...
# Done
#          date  vixo  vixh  vixl   vix   vxoo   vxoh   vxol    vxo  vxno  vxnh  \
# 0  1986-01-02  <NA>  <NA>  <NA>  <NA>  17.93  18.71   17.4  18.07  <NA>  <NA>
# 1  1986-01-03  <NA>  <NA>  <NA>  <NA>  19.04   19.1  17.72  17.96  <NA>  <NA>
# 2  1986-01-06  <NA>  <NA>  <NA>  <NA>  17.99  18.17  17.05  17.05  <NA>  <NA>
# 3  1986-01-07  <NA>  <NA>  <NA>  <NA>  18.01  18.11   17.3  17.39  <NA>  <NA>
# 4  1986-01-08  <NA>  <NA>  <NA>  <NA>  18.04  21.15  16.63  19.97  <NA>  <NA>
#
#    vxnl   vxn  vxdo  vxdh  vxdl   vxd
# 0  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 1  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 2  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 3  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 4  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>

# %% [markdown]
# # Treasury and Inflation

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

contents = conn.raw_sql("SELECT * FROM crsp_a_indexes.mcti LIMIT 5")

print(contents)

conn.close()
# Out:
# Loading library list...
# Done
#         caldt b30ret    b30ind b20ret    b20ind b10ret    b10ind b7ret  \
# 0  1925-12-31   <NA>  50.27088   <NA>  49.26875   <NA>  46.97544  <NA>
# 1  1926-01-30   <NA>  50.27088   <NA>  49.26875   <NA>  46.97544  <NA>
# 2  1926-02-27   <NA>  50.27088   <NA>  49.26875   <NA>  46.97544  <NA>
# 3  1926-03-31   <NA>  50.27088   <NA>  49.26875   <NA>  46.97544  <NA>
# 4  1926-04-30   <NA>  50.27088   <NA>  49.26875   <NA>  46.97544  <NA>
#
#      b7ind b5ret  ...  b2ret     b2ind  b1ret     b1ind    t90ret    t90ind  \
# 0  40.4141  <NA>  ...   <NA>  39.54598   <NA>  39.84357      <NA>  34.83693
# 1  40.4141  <NA>  ...   <NA>  39.54598   <NA>  39.84357  0.004042  34.97774
# 2  40.4141  <NA>  ...   <NA>  39.54598   <NA>  39.84357  0.003237  35.09096
# 3  40.4141  <NA>  ...   <NA>  39.54598   <NA>  39.84357  0.002778  35.18843
# 4  40.4141  <NA>  ...   <NA>  39.54598   <NA>  39.84357  0.003072  35.29653
#
#      t30ret    t30ind    cpiret  cpiind
# ...

# %% [markdown]
# # FX Rates
#
# Had to change this, as the factset data finished in 2021, to frb

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

contents = conn.raw_sql("SELECT * FROM factset_common.fx_rates_usd LIMIT 5")

contents_2 = conn.raw_sql("SELECT * FROM frb_all.fx_daily LIMIT 5")

print(contents)
print(contents_2)

conn.close()
# Out:
# Loading library list...
# Done
#   iso_currency        date  exch_rate_usd  exch_rate_per_usd
# 0          AED  1966-01-31           0.21             4.7619
# 1          AED  1966-02-01           0.21             4.7619
# 2          AED  1966-02-02           0.21             4.7619
# 3          AED  1966-02-03           0.21             4.7619
# 4          AED  1966-02-04           0.21             4.7619
#          date  dexusal   dexalus dexbzus  dexcaus dexchus  dexdnus dexhkus  \
# 0  1971-01-04   1.1127  0.898715    <NA>   1.0109    <NA>    7.485    <NA>
# 1  1971-01-05   1.1132  0.898311    <NA>   1.0102    <NA>   7.4872    <NA>
# 2  1971-01-06    1.114  0.897666    <NA>   1.0106    <NA>   7.4839    <NA>
# 3  1971-01-07   1.1138  0.897827    <NA>   1.0148    <NA>    7.485    <NA>
# 4  1971-01-08   1.1124  0.898957    <NA>   1.0154    <NA>    7.485    <NA>
#
#   dexinus  dexjpus  ... execus  dexuseu dexeuus  dtwexb  dtwexbgs  dtwexm  \
# ...

# %% [markdown]
# # Pastor Stamburgh

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

contents = conn.raw_sql("SELECT * FROM ff_all.liq_ps LIMIT 5")

print(contents)

conn.close()
# Out:
# Loading library list...
# Done
#      yearmm        date  ps_level  ps_innov  ps_vwf
# 0  196208.0  1962-08-31 -0.017537   0.00426   -99.0
# 1  196209.0  1962-09-28 -0.004075  0.011763   -99.0
# 2  196210.0  1962-10-31 -0.104212 -0.074041   -99.0
# 3  196211.0  1962-11-30 -0.019742  0.028183   -99.0
# 4  196212.0  1962-12-31 -0.005089  0.012929   -99.0

# %% [markdown]
# # Fama French

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

contents = conn.raw_sql("SELECT * FROM ff_all.fivefactors_daily LIMIT 5")

print(contents)

conn.close()
# Out:
# Loading library list...
# Done
#          date   mktrf     smb     hml     rmw     cma      rf     umd
# 0  1963-07-01 -0.0067     0.0 -0.0034 -0.0001  0.0016  0.0001 -0.0023
# 1  1963-07-02  0.0079 -0.0026  0.0026 -0.0007  -0.002  0.0001  0.0044
# 2  1963-07-03  0.0063 -0.0017 -0.0009  0.0018 -0.0034  0.0001  0.0038
# 3  1963-07-05   0.004  0.0008 -0.0027  0.0009 -0.0034  0.0001  0.0006
# 4  1963-07-08 -0.0063  0.0004 -0.0018 -0.0029  0.0014  0.0001 -0.0045

# %% [markdown]
# # International Index Returns

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

contents = conn.raw_sql("SELECT * FROM wrdsapps_windices.dwcountryreturns LIMIT 5")

print(contents)

conn.close()
# Out:
# Loading library list...
# Done
#    fic        date   portret  portretx     n    country currency
# 0  AUS  1986-07-01 -0.001263 -0.001263  54.0  AUSTRALIA      AUD
# 1  AUS  1986-07-02  -0.02491  -0.02491  54.0  AUSTRALIA      AUD
# 2  AUS  1986-07-03 -0.006412 -0.006412  54.0  AUSTRALIA      AUD
# 3  AUS  1986-07-04  0.002196  0.001233  54.0  AUSTRALIA      AUD
# 4  AUS  1986-07-07 -0.007114 -0.007114  54.0  AUSTRALIA      AUD

# %% [markdown]
# # Open Asset Pricing Data

# %%
import pandas as pd
import duckdb as db


df = pd.read_parquet("factors.parquet")

# %%
df.info()

display(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5416424 entries, 0 to 5416423
# Columns: 211 entries, permno to zerotrade6M
# dtypes: float64(208), int64(2), object(1)
# memory usage: 8.5+ GB
# Index(['permno', 'yyyymm', 'AM', 'AOP', 'AbnormalAccruals', 'Accruals',
#        'AccrualsBM', 'Activism1', 'Activism2', 'AdExp',
#        ...
#        'retConglomerate', 'roaq', 'sfe', 'sinAlgo', 'skew1', 'std_turn',
#        'tang', 'zerotrade12M', 'zerotrade1M', 'zerotrade6M'],
#       dtype='object', length=211)

# %% [markdown]
# # LSEG IBES Data
#
# 1. ibes.statsumu_epsus (Unadjusted Summary Statistics)
#
# 2. ibes.actu_epsus (Unadjusted Actuals)
#
# 3. ibes.recddet (Recommendation Detail)
#
# 4. ibes.ptgdet (Price Target Detail)
#
# 5. ibes.idsum (IBES Identifier Summary)
#
# 6. crsp.stocknames (CRSP Stock Names)

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='ibes', table='statsumu_epsus')

contents = conn.raw_sql("SELECT * FROM ibes.statsumu_epsus LIMIT 5")

print(contents)

print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 14915650 rows in ibes.statsumu_epsus.
#   ticker     cusip oftic               cname    statpers measure fiscalp fpi  \
# 0   0000  87482X10  TLMR  TALMER BANCORP INC  2014-04-17     EPS     QTR   6
# 1   0000  87482X10  TLMR  TALMER BANCORP INC  2014-05-15     EPS     QTR   6
# 2   0000  87482X10  TLMR  TALMER BANCORP INC  2014-06-19     EPS     QTR   6
# 3   0000  87482X10  TLMR  TALMER BANCORP INC  2014-07-17     EPS     QTR   6
# 4   0000  87482X10  TLMR  TALMER BANCORP INC  2014-04-17     EPS     QTR   7
#
#   estflag curcode  numest  numup  numdown  medest  meanest  stdev  highest  \
# 0       P     USD     4.0    0.0      4.0    0.07     0.08   0.01      0.1
# 1       P     USD     5.0    3.0      0.0    0.13     0.13   0.01     0.15
# 2       P     USD     5.0    0.0      0.0    0.13     0.13   0.01     0.15
# 3       P     USD     5.0    0.0      0.0    0.13     0.13   0.01     0.15
# ...

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='ibes', table='recddet')

contents = conn.raw_sql("SELECT * FROM ibes.recddet LIMIT 5")

print(contents)

print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 3289098 rows in ibes.recddet.
#   ticker     cusip           cname oftic     actdats   estimid  \
# 0   0000  87482X10  TALMER BANCORP  TLMR  2014-03-10  RBCDOMIN
# 1   0000  87482X10  TALMER BANCORP  TLMR  2014-03-11  JPMORGAN
# 2   0000  87482X10  TALMER BANCORP  TLMR  2014-03-11     KEEFE
# 3   0000  87482X10  TALMER BANCORP  TLMR  2014-03-11   RAYMOND
# 4   0000  87482X10  TALMER BANCORP  TLMR  2014-03-11    STERNE
#
#            analyst ereccd       etext ireccd       itext  emaskcd   amaskcd  \
# 0  ARFSTROM      J      2  OUTPERFORM      2         BUY    659.0   71182.0
# 1  ALEXOPOULOS   S   <NA>  OVERWEIGHT      2         BUY   1243.0   79092.0
# 2  MCGRATTY      C      2  OUTPERFORM      2         BUY   1308.0  119962.0
# 3  LONG          D      1  STRONG BUY      1  STRONG BUY   1929.0   80474.0
# 4  GREEN         P      2     NEUTRAL      3        HOLD   2209.0   50789.0
#
# ...

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='ibes', table='actu_epsus')

contents = conn.raw_sql("SELECT * FROM ibes.actu_epsus LIMIT 5")

print(contents)

print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 1310008 rows in ibes.actu_epsus.
#   ticker cusip oftic cname       pends measure pdicity     anndats   anntims  \
# 0   0000  <NA>  <NA>  <NA>  2012-12-31     EPS     ANN  2014-02-14  18:41:00
# 1   0000  <NA>  <NA>  <NA>  2012-12-31     EPS     QTR  2014-02-14  18:41:00
# 2   0000  <NA>  <NA>  <NA>  2013-01-31     EPS     QTR  2014-02-14  18:41:00
# 3   0000  <NA>  <NA>  <NA>  2013-03-31     EPS     QTR  2014-02-14  18:41:00
# 4   0000  <NA>  <NA>  <NA>  2013-04-30     EPS     QTR  2014-02-14  18:41:00
#
#       actdats   acttims value curr_act  usfirm
# 0  2014-03-10  13:41:57  <NA>      USD       1
# 1  2014-03-10  13:41:57  <NA>      USD       1
# 2  2014-03-10  05:58:45  <NA>      USD       1
# 3  2014-03-10  13:42:58  <NA>      USD       1
# 4  2014-03-10  06:11:05  <NA>      USD       1
#         name  nullable              type  \
# 0     ticker      True        VARCHAR(6)
# 1      cusip      True        VARCHAR(8)
# ...

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='ibes', table='ptgdet')

contents = conn.raw_sql("SELECT * FROM ibes.ptgdet LIMIT 5")

print(contents)

print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 7509626 rows in ibes.ptgdet.
#   ticker     cusip oftic           cname     actdats   estimid  \
# 0   0000  87482X10  TLMR  TALMER BANCORP  2014-03-10  RBCDOMIN
# 1   0000  87482X10  TLMR  TALMER BANCORP  2014-03-11     KEEFE
# 2   0000  87482X10  TLMR  TALMER BANCORP  2014-03-11  JPMORGAN
# 3   0000  87482X10  TLMR  TALMER BANCORP  2014-03-11   RAYMOND
# 4   0000  87482X10  TLMR  TALMER BANCORP  2014-04-08  JPMORGAN
#
#                 alysnam horizon  value estcur curr   amaskcd  usfirm measure  \
# 0  ARFSTROM           J      12   16.0    USD  USD   71182.0       1     PTG
# 1  MCGRATTY           C      12   16.0    USD  USD  119962.0       1     PTG
# 2  ALEXOPOULOS        S      12   16.0    USD  USD   79092.0       1     PTG
# 3  LONG               D      12   16.0    USD  USD   80474.0       1     PTG
# 4  ALEXOPOULOS        S      12   16.5    USD  USD   79092.0       1     PTG
#
#     acttims     anndats   anntims
# ...

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='ibes', table='idsum')

contents = conn.raw_sql("SELECT * FROM ibes.idsum LIMIT 5")

print(contents)

print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 281042 rows in ibes.idsum.
#   ticker     cusip oftic               cname  dilfac pdi ccopcf  tnthfac  \
# 0   0000  87482X10  TLMR  TALMER BANCORP INC     1.0   P   <NA>      0.0
# 1   0000  87482X10  TLMR  TALMER BANCORP INC     1.0   D   <NA>      0.0
# 2   0001  26878510   EPE      EP ENERGY CORP     1.0   P   <NA>      0.0
# 3   0001  26878510   EPE      EP ENERGY CORP     1.0   D   <NA>      0.0
# 4   0001  26878510  EPEG      EP ENERGY CORP     1.0   D   <NA>      0.0
#
#   instrmnt exchcd country compflag  usfirm      sdates
# 0        S      F      NA     <NA>       1  2014-02-20
# 1        S      F      NA     <NA>       1  2014-03-20
# 2        S      A      NA     <NA>       1  2014-02-20
# 3        S      A      NA     <NA>       1  2014-03-20
# 4        S      A      NA     <NA>       1  2019-06-20
#         name  nullable              type  \
# 0     ticker      True        VARCHAR(6)
# ...

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='crsp', table='stocknames')

contents = conn.raw_sql("SELECT * FROM crsp.stocknames LIMIT 5")

print(contents)

print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 83280 rows in crsp.stocknames.
#    permno      namedt   nameenddt  shrcd  exchcd  siccd    ncusip ticker  \
# 0   10000  1986-01-07  1987-06-11     10       3   3990  68391610  OMFGA
# 1   10001  1986-01-09  1993-11-21     11       3   4920  39040610   GFGC
# 2   10001  1993-11-22  2008-02-04     11       3   4920  29274A10   EWST
# 3   10001  2008-02-05  2009-08-03     11       3   4920  29274A20   EWST
# 4   10001  2009-08-04  2009-12-17     11       3   4920  29269V10   EGAS
#
#                       comnam shrcls  permco  hexcd     cusip     st_date  \
# 0  OPTIMUM MANUFACTURING INC      A    7952      3  68391610  1986-01-07
# 1         GREAT FALLS GAS CO   <NA>    7953      2  36720410  1986-01-09
# 2            ENERGY WEST INC   <NA>    7953      2  36720410  1986-01-09
# 3            ENERGY WEST INC   <NA>    7953      2  36720410  1986-01-09
# 4                 ENERGY INC   <NA>    7953      2  36720410  1986-01-09
#
# ...

# %% [markdown]
# # Some are xepsus

# %%
import wrds

conn = wrds.Connection(wrds_username='henrylavender')

description = conn.describe_table(library='ibes', table='statsumu_xepsus')

contents = conn.raw_sql("SELECT * FROM ibes.statsumu_xepsus LIMIT 5")

print(contents)

print(description)

conn.close()
# Out:
# Loading library list...
# Done
# Approximately 21939383 rows in ibes.statsumu_xepsus.
#   ticker     cusip oftic               cname    statpers measure fiscalp fpi  \
# 0   0000  87482X10  TLMR  TALMER BANCORP INC  2014-04-17     BPS     QTR   6
# 1   0000  87482X10  TLMR  TALMER BANCORP INC  2014-05-15     BPS     QTR   6
# 2   0000  87482X10  TLMR  TALMER BANCORP INC  2014-06-19     BPS     QTR   6
# 3   0000  87482X10  TLMR  TALMER BANCORP INC  2014-07-17     BPS     QTR   6
# 4   0000  87482X10  TLMR  TALMER BANCORP INC  2014-04-17     BPS     QTR   7
#
#   estflag curcode  numest  numup  numdown  medest  meanest  stdev  highest  \
# 0       P     USD     4.0    0.0      0.0    9.84     9.81   0.23    10.03
# 1       P     USD     4.0    3.0      1.0   10.11    10.13   0.06    10.22
# 2       P     USD     4.0    0.0      1.0    10.1    10.13   0.06    10.22
# 3       P     USD     4.0    0.0      0.0    10.1    10.13   0.06    10.22
# ...
